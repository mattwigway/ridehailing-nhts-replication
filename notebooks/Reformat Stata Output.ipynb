# %%
import pandas as pd
import re
import numpy as np

# %%
main = pd.read_table('../stata/logit.tsv', skiprows=[0, 1, 3, 4])
main['VARIABLES'] = main.VARIABLES.apply(lambda s: s.replace('b.', '.').replace('o.', '.') if not pd.isnull(s) else s)
main = main.set_index('VARIABLES')

# %%
income = pd.read_table('../stata/income_hhsize.tsv', skiprows=[0, 2, 3, 4, 5, 6])

for rown, row in income.iloc[0:4].iterrows():
    var = row.VARIABLES.replace('bn', '').replace('b.', '.').replace('o.', '.')
    
    for incomeCategory in [1, 2, 3]:
        for suffix, mainCol in [('', 'coef'), ('.1', 'pval.1'), ('.2', 'ci_low'), ('.3', 'ci_high')]:
            col = f'{incomeCategory}.incomeCategory{suffix}'
            
            mainRow = f'{var}#{incomeCategory}.incomeCategory'
            
            main.loc[mainRow, mainCol] = row.loc[col]

# %%
altt = pd.read_table('../stata/alt_hhsize.tsv', skiprows=[0, 2])

for rown, row in altt.iloc[0:4].iterrows():
    var = row.VARIABLES.replace('bn', '').replace('b.', '.').replace('o.', '.')
    
    for alt in ['pubTransCount', 'bikeCount', 'walkCount', 'vehPerHHMember', 'CNTTDTR']:
        for suffix, mainCol in [('', 'coef'), ('.1', 'pval.1'), ('.2', 'ci_low'), ('.3', 'ci_high')]:
            col = f'{alt}{suffix}'
            mainRow = f'{var}#c.{alt}'
            
            main.loc[mainRow, mainCol] = row.loc[col]

# %%
dens = pd.read_table('../stata/density_msaSize.tsv', skiprows=[0, 2, 3, 4, 5, 6, 7, 8])
for rown, row in dens.iloc[0:6].iterrows():
    var = row.VARIABLES.replace('bn', '').replace('b.', '.').replace('o.', '.')
    
    for densCategory in [1, 2, 3, 4, 5, 6, 7]:
        for suffix, mainCol in [('', 'coef'), ('.1', 'pval.1'), ('.2', 'ci_low'), ('.3', 'ci_high')]:
            col = f'{densCategory}.density{suffix}'
            
            mainRow = f'{var}#{densCategory}.density'
            
            main.loc[mainRow, mainCol] = row.loc[col]

# %%
with pd.option_context('display.max_rows', 100):
    display(main)
# Out:
#                                                                               LABELS  \
# VARIABLES
# 2.hhSizeTopcode4                                                  hhSizeTopcode4 = 2
# 3.hhSizeTopcode4                                                  hhSizeTopcode4 = 3
# 4.hhSizeTopcode4                                                  hhSizeTopcode4 = 4
# 1.isWorker                                                              isWorker = 1
# 1.homeowner                                                            homeowner = 1
# 1.sex                                                                  sex = 1, Male
# 1.children0to12                                                    children0to12 = 1
# 1.children13to17                                                  children13to17 = 1
# 1.unrelated                                                            unrelated = 1
# 1.outOfTown                                                            outOfTown = 1
# 1.dailySmartphoneUseHH                                      dailySmartphoneUseHH = 1
# 0.incomeCategory#c.vehPerHHMember                                                NaN
# 1.incomeCategory#c.vehPerHHMember                                                NaN
# 2.incomeCategory#c.vehPerHHMember                                                NaN
# 3.incomeCategory#c.vehPerHHMember                                                NaN
# 0.incomeCategory#c.pubTransCount                                                 NaN
# 1.incomeCategory#c.pubTransCount                                                 NaN
# 2.incomeCategory#c.pubTransCount                                                 NaN
# 3.incomeCategory#c.pubTransCount                                                 NaN
# 0.incomeCategory#c.walkCount                                                     NaN
# 1.incomeCategory#c.walkCount                                                     NaN
# 2.incomeCategory#c.walkCount                                                     NaN
# 3.incomeCategory#c.walkCount                                                     NaN
# 0.incomeCategory#c.bikeCount                                                     NaN
# 1.incomeCategory#c.bikeCount                                                     NaN
# 2.incomeCategory#c.bikeCount                                                     NaN
# 3.incomeCategory#c.bikeCount                                                     NaN
# 0.incomeCategory#c.CNTTDTR                                                       NaN
# 1.incomeCategory#c.CNTTDTR                                                       NaN
# 2.incomeCategory#c.CNTTDTR                                                       NaN
# 3.incomeCategory#c.CNTTDTR                                                       NaN
# 1.hhSizeTopcode4#0.incomeCategory                                                NaN
# 1.hhSizeTopcode4#1.incomeCategory                                                NaN
# 1.hhSizeTopcode4#2.incomeCategory                                                NaN
# 1.hhSizeTopcode4#3.incomeCategory                                                NaN
# 2.hhSizeTopcode4#0.incomeCategory                                                NaN
# 2.hhSizeTopcode4#1.incomeCategory                                                NaN
# 2.hhSizeTopcode4#2.incomeCategory                                                NaN
# 2.hhSizeTopcode4#3.incomeCategory                                                NaN
# 3.hhSizeTopcode4#0.incomeCategory                                                NaN
# 3.hhSizeTopcode4#1.incomeCategory                                                NaN
# 3.hhSizeTopcode4#2.incomeCategory                                                NaN
# 3.hhSizeTopcode4#3.incomeCategory                                                NaN
# 4.hhSizeTopcode4#0.incomeCategory                                                NaN
# 4.hhSizeTopcode4#1.incomeCategory                                                NaN
# 4.hhSizeTopcode4#2.incomeCategory                                                NaN
# 4.hhSizeTopcode4#3.incomeCategory                                                NaN
# 1.race                                    race = 1, American Indian or Alaska Native
# 2.race                                                               race = 2, Asian
# 3.race                                           race = 3, Black or African American
# ...                                                                              ...
# 3.msaSize#2.density                                                              NaN
# 3.msaSize#3.density                                                              NaN
# 3.msaSize#4.density                                                              NaN
# 3.msaSize#5.density                                                              NaN
# 3.msaSize#6.density                                                              NaN
# 3.msaSize#7.density                                                              NaN
# 4.msaSize#0.density                                                              NaN
# 4.msaSize#1.density                                                              NaN
# 4.msaSize#2.density                                                              NaN
# 4.msaSize#3.density                                                              NaN
# 4.msaSize#4.density                                                              NaN
# 4.msaSize#5.density                                                              NaN
# 4.msaSize#6.density                                                              NaN
# 4.msaSize#7.density                                                              NaN
# 5.msaSize#0.density                                                              NaN
# 5.msaSize#1.density                                                              NaN
# 5.msaSize#2.density                                                              NaN
# 5.msaSize#3.density                                                              NaN
# 5.msaSize#4.density                                                              NaN
# 5.msaSize#5.density                                                              NaN
# 5.msaSize#6.density                                                              NaN
# 5.msaSize#7.density                                                              NaN
# 1.msaRail                                                                msaRail = 1
# 1.season                                                          season = 1, Spring
# 2.season                                                          season = 2, Summer
# 3.season                                                          season = 3, Winter
# 1.geographicCellDerived                        geographicCellDerived = 1, California
# 2.geographicCellDerived            geographicCellDerived = 2, Census division 1 (...
# 3.geographicCellDerived            geographicCellDerived = 3, Census division 2 (...
# 4.geographicCellDerived            geographicCellDerived = 4, Census division 3 (...
# 5.geographicCellDerived            geographicCellDerived = 5, Census division 4 (...
# 6.geographicCellDerived            geographicCellDerived = 6, Census division 5 (...
# 7.geographicCellDerived            geographicCellDerived = 7, Census division 6 (...
# 8.geographicCellDerived            geographicCellDerived = 8, Census division 7 (...
# 9.geographicCellDerived            geographicCellDerived = 9, Census division 8 (...
# 10.geographicCellDerived           geographicCellDerived = 10, Census division 9 ...
# 11.geographicCellDerived                         geographicCellDerived = 11, Georgia
# 12.geographicCellDerived                            geographicCellDerived = 12, Iowa
# 13.geographicCellDerived                        geographicCellDerived = 13, Maryland
# 14.geographicCellDerived                  geographicCellDerived = 14, New York State
# 15.geographicCellDerived                  geographicCellDerived = 15, North Carolina
# 16.geographicCellDerived                        geographicCellDerived = 16, Oklahoma
# 17.geographicCellDerived                  geographicCellDerived = 17, South Carolina
# 18.geographicCellDerived                           geographicCellDerived = 18, Texas
# 19.geographicCellDerived                       geographicCellDerived = 19, Wisconsin
# Constant                                                                    Constant
# NaN                                                                              NaN
# Observations                                                                     NaN
# Robust seeform in parentheses                                                    NaN
# *** p<0.001, ** p<0.01, * p<0.05                                                 NaN
#
#                                     coefEform          pval  ci_lowEform  \
# VARIABLES
# 2.hhSizeTopcode4                     1.380***  6.590000e-04      1.14600
# 3.hhSizeTopcode4                        0.913  4.920000e-01      0.70400
# 4.hhSizeTopcode4                      0.687**  7.670000e-03      0.52100
# 1.isWorker                           1.412***  0.000000e+00      1.34400
# 1.homeowner                          0.752***  0.000000e+00      0.71300
# 1.sex                                1.135***  0.000000e+00      1.10000
# 1.children0to12                         1.000  9.980000e-01      0.92800
# 1.children13to17                        0.980  6.420000e-01      0.90100
# 1.unrelated                          2.045***  0.000000e+00      1.80100
# 1.outOfTown                          2.110***  0.000000e+00      1.94100
# 1.dailySmartphoneUseHH               3.141***  0.000000e+00      2.86400
# 0.incomeCategory#c.vehPerHHMember     0.794**  7.810000e-03      0.66900
# 1.incomeCategory#c.vehPerHHMember    0.770***  7.930000e-04      0.66100
# 2.incomeCategory#c.vehPerHHMember    0.753***  5.590000e-10      0.68900
# 3.incomeCategory#c.vehPerHHMember     0.918**  9.960000e-03      0.86000
# 0.incomeCategory#c.pubTransCount     1.040***  0.000000e+00      1.03100
# 1.incomeCategory#c.pubTransCount     1.048***  0.000000e+00      1.03800
# 2.incomeCategory#c.pubTransCount     1.060***  0.000000e+00      1.05200
# 3.incomeCategory#c.pubTransCount     1.065***  0.000000e+00      1.05900
# 0.incomeCategory#c.walkCount           1.007*  1.210000e-02      1.00100
# 1.incomeCategory#c.walkCount         1.012***  3.450000e-07      1.00700
# 2.incomeCategory#c.walkCount         1.013***  0.000000e+00      1.00900
# 3.incomeCategory#c.walkCount         1.016***  0.000000e+00      1.01300
# 0.incomeCategory#c.bikeCount            1.012  1.250000e-01      0.99700
# 1.incomeCategory#c.bikeCount         1.048***  5.700000e-05      1.02400
# 2.incomeCategory#c.bikeCount          1.035**  1.370000e-03      1.01300
# 3.incomeCategory#c.bikeCount         1.050***  2.460000e-08      1.03200
# 0.incomeCategory#c.CNTTDTR             1.024*  3.670000e-02      1.00100
# 1.incomeCategory#c.CNTTDTR            1.030**  2.240000e-03      1.01100
# 2.incomeCategory#c.CNTTDTR           1.042***  7.500000e-10      1.02800
# 3.incomeCategory#c.CNTTDTR           1.043***  0.000000e+00      1.03300
# 1.hhSizeTopcode4#0.incomeCategory           1           NaN      1.00000
# 1.hhSizeTopcode4#1.incomeCategory       1.270  1.100000e-01      0.94700
# 1.hhSizeTopcode4#2.incomeCategory    2.083***  4.540000e-09      1.63000
# 1.hhSizeTopcode4#3.incomeCategory    3.500***  0.000000e+00      2.74500
# 2.hhSizeTopcode4#0.incomeCategory           1           NaN      1.00000
# 2.hhSizeTopcode4#1.incomeCategory       0.920  5.500000e-01      0.70100
# 2.hhSizeTopcode4#2.incomeCategory     1.456**  1.420000e-03      1.15600
# 2.hhSizeTopcode4#3.incomeCategory    2.867***  0.000000e+00      2.30100
# 3.hhSizeTopcode4#0.incomeCategory           1           NaN      1.00000
# 3.hhSizeTopcode4#1.incomeCategory       0.956  7.780000e-01      0.70000
# 3.hhSizeTopcode4#2.incomeCategory       1.190  2.040000e-01      0.90900
# 3.hhSizeTopcode4#3.incomeCategory    2.602***  0.000000e+00      2.02100
# 4.hhSizeTopcode4#0.incomeCategory           1           NaN      1.00000
# 4.hhSizeTopcode4#1.incomeCategory       0.832  2.550000e-01      0.60700
# 4.hhSizeTopcode4#2.incomeCategory       1.135  3.500000e-01      0.87000
# 4.hhSizeTopcode4#3.incomeCategory    2.647***  0.000000e+00      2.06000
# 1.race                                  0.812  1.520000e-01      0.61100
# 2.race                               0.779***  4.130000e-09      0.71700
# 3.race                               0.762***  2.050000e-10      0.70000
# ...                                       ...           ...          ...
# 3.msaSize#2.density                  2.077***  7.580000e-05      1.44600
# 3.msaSize#3.density                  2.317***  2.010000e-06      1.63900
# 3.msaSize#4.density                  3.097***  5.070000e-11      2.21100
# 3.msaSize#5.density                  3.076***  1.510000e-10      2.18100
# 3.msaSize#6.density                  3.632***  8.870000e-10      2.40500
# 3.msaSize#7.density                  5.110***  7.640000e-06      2.50100
# 4.msaSize#0.density                         1           NaN      1.00000
# 4.msaSize#1.density                     1.242  2.590000e-01      0.85300
# 4.msaSize#2.density                  2.044***  2.230000e-04      1.39800
# 4.msaSize#3.density                  2.118***  3.450000e-05      1.48500
# 4.msaSize#4.density                  2.356***  1.010000e-06      1.67100
# 4.msaSize#5.density                  2.876***  8.590000e-10      2.05200
# 4.msaSize#6.density                  2.755***  4.340000e-08      1.91700
# 4.msaSize#7.density                  7.944***  0.000000e+00      4.48300
# 5.msaSize#0.density                         1           NaN      1.00000
# 5.msaSize#1.density                   1.686**  4.870000e-03      1.17200
# 5.msaSize#2.density                  2.087***  6.870000e-05      1.45300
# 5.msaSize#3.density                  2.756***  1.040000e-08      1.94800
# 5.msaSize#4.density                  3.168***  0.000000e+00      2.25400
# 5.msaSize#5.density                  3.561***  0.000000e+00      2.53900
# 5.msaSize#6.density                  4.605***  0.000000e+00      3.26500
# 5.msaSize#7.density                  6.967***  0.000000e+00      4.87000
# 1.msaRail                               0.979  5.740000e-01      0.90800
# 1.season                             0.798***  8.980000e-11      0.74500
# 2.season                             0.820***  0.000000e+00      0.77600
# 3.season                                0.999  9.580000e-01      0.94500
# 1.geographicCellDerived               1.315**  1.750000e-03      1.10800
# 2.geographicCellDerived                 0.834  1.350000e-01      0.65700
# 3.geographicCellDerived                0.753*  2.760000e-02      0.58500
# 4.geographicCellDerived                 0.828  8.170000e-02      0.66900
# 5.geographicCellDerived              0.585***  3.090000e-05      0.45400
# 6.geographicCellDerived                 1.121  2.790000e-01      0.91200
# 7.geographicCellDerived                 0.871  3.560000e-01      0.65000
# 8.geographicCellDerived                 1.066  7.620000e-01      0.70300
# 9.geographicCellDerived                 0.834  1.370000e-01      0.65600
# 10.geographicCellDerived             0.578***  3.550000e-05      0.44600
# 11.geographicCellDerived              1.283**  8.420000e-03      1.06600
# 12.geographicCellDerived               0.746*  1.750000e-02      0.58500
# 13.geographicCellDerived                0.810  1.090000e-01      0.62600
# 14.geographicCellDerived             0.430***  0.000000e+00      0.35700
# 15.geographicCellDerived                1.083  4.190000e-01      0.89300
# 16.geographicCellDerived                0.898  4.780000e-01      0.66700
# 17.geographicCellDerived                1.072  5.030000e-01      0.87400
# 18.geographicCellDerived              0.779**  3.970000e-03      0.65700
# 19.geographicCellDerived               0.784*  1.010000e-02      0.65100
# Constant                           0.00387***  0.000000e+00      0.00268
# NaN                                       NaN           NaN          NaN
# Observations                          224,720           NaN          NaN
# Robust seeform in parentheses             NaN           NaN          NaN
# *** p<0.001, ** p<0.01, * p<0.05          NaN           NaN          NaN
#
#                                    ci_highEform         coef        pval.1  \
# VARIABLES
# 2.hhSizeTopcode4                        1.66100      0.00732  1.910000e-01
# 3.hhSizeTopcode4                        1.18400   -0.0314***  2.140000e-07
# 4.hhSizeTopcode4                        0.90500   -0.0498***  0.000000e+00
# 1.isWorker                              1.48300    0.0226***  0.000000e+00
# 1.homeowner                             0.79300   -0.0200***  0.000000e+00
# 1.sex                                   1.17100   0.00864***  0.000000e+00
# 1.children0to12                         1.07800     6.59e-06  9.980000e-01
# 1.children13to17                        1.06600     -0.00136  6.410000e-01
# 1.unrelated                             2.32200    0.0565***  0.000000e+00
# 1.outOfTown                             2.29300    0.0615***  0.000000e+00
# 1.dailySmartphoneUseHH                  3.44400    0.0604***  0.000000e+00
# 0.incomeCategory#c.vehPerHHMember       0.94100    -0.0111**  8.500000e-03
# 1.incomeCategory#c.vehPerHHMember       0.89700   -0.0122***  8.860000e-04
# 2.incomeCategory#c.vehPerHHMember       0.82400   -0.0167***  6.840000e-10
# 3.incomeCategory#c.vehPerHHMember       0.98000   -0.00909**  9.920000e-03
# 0.incomeCategory#c.pubTransCount        1.04900   0.00189***  0.000000e+00
# 1.incomeCategory#c.pubTransCount        1.05800   0.00218***  0.000000e+00
# 2.incomeCategory#c.pubTransCount        1.06700   0.00343***  0.000000e+00
# 3.incomeCategory#c.pubTransCount        1.07100   0.00663***  0.000000e+00
# 0.incomeCategory#c.walkCount            1.01200    0.000317*  1.230000e-02
# 1.incomeCategory#c.walkCount            1.01600  0.000541***  3.590000e-07
# 2.incomeCategory#c.walkCount            1.01600  0.000753***  0.000000e+00
# 3.incomeCategory#c.walkCount            1.02000   0.00172***  0.000000e+00
# 0.incomeCategory#c.bikeCount            1.02700     0.000556  1.250000e-01
# 1.incomeCategory#c.bikeCount            1.07200   0.00217***  5.880000e-05
# 2.incomeCategory#c.bikeCount            1.05700    0.00202**  1.380000e-03
# 3.incomeCategory#c.bikeCount            1.06800   0.00518***  2.420000e-08
# 0.incomeCategory#c.CNTTDTR              1.04700     0.00113*  3.610000e-02
# 1.incomeCategory#c.CNTTDTR              1.05000    0.00138**  2.300000e-03
# 2.incomeCategory#c.CNTTDTR              1.05600   0.00244***  8.400000e-10
# 3.incomeCategory#c.CNTTDTR              1.05300   0.00443***  0.000000e+00
# 1.hhSizeTopcode4#0.incomeCategory       1.00000          NaN           NaN
# 1.hhSizeTopcode4#1.incomeCategory       1.70200    0.0240***  3.990000e-07
# 1.hhSizeTopcode4#2.incomeCategory       2.66200    0.0734***  0.000000e+00
# 1.hhSizeTopcode4#3.incomeCategory       4.46300     0.155***  0.000000e+00
# 2.hhSizeTopcode4#0.incomeCategory       1.00000          NaN           NaN
# 2.hhSizeTopcode4#1.incomeCategory       1.20800     0.000924  8.240000e-01
# 2.hhSizeTopcode4#2.incomeCategory       1.83500    0.0324***  0.000000e+00
# 2.hhSizeTopcode4#3.incomeCategory       3.57300     0.107***  0.000000e+00
# 3.hhSizeTopcode4#0.incomeCategory       1.00000          NaN           NaN
# 3.hhSizeTopcode4#1.incomeCategory       1.30600      0.00197  7.400000e-01
# 3.hhSizeTopcode4#2.incomeCategory       1.55800     0.0169**  2.260000e-03
# 3.hhSizeTopcode4#3.incomeCategory       3.34900    0.0909***  0.000000e+00
# 4.hhSizeTopcode4#0.incomeCategory       1.00000          NaN           NaN
# 4.hhSizeTopcode4#1.incomeCategory       1.14100     -0.00410  4.460000e-01
# 4.hhSizeTopcode4#2.incomeCategory       1.48100      0.0115*  2.000000e-02
# 4.hhSizeTopcode4#3.incomeCategory       3.40100    0.0806***  0.000000e+00
# 1.race                                  1.08000      -0.0139  1.290000e-01
# 2.race                                  0.84700   -0.0165***  4.270000e-10
# 3.race                                  0.82800   -0.0179***  0.000000e+00
# ...                                         ...          ...           ...
# 3.msaSize#2.density                     2.98200    0.0252***  1.330000e-05
# 3.msaSize#3.density                     3.27800    0.0304***  1.950000e-08
# 3.msaSize#4.density                     4.34000    0.0465***  0.000000e+00
# 3.msaSize#5.density                     4.33800    0.0461***  0.000000e+00
# 3.msaSize#6.density                     5.48700    0.0569***  1.270000e-08
# 3.msaSize#7.density                    10.44000     0.0832**  3.260000e-03
# 4.msaSize#0.density                     1.00000          NaN           NaN
# 4.msaSize#1.density                     1.81000       0.0102  2.400000e-01
# 4.msaSize#2.density                     2.98700    0.0407***  5.400000e-05
# 4.msaSize#3.density                     3.02100    0.0433***  1.090000e-06
# 4.msaSize#4.density                     3.32300    0.0514***  6.270000e-10
# 4.msaSize#5.density                     4.03200    0.0682***  0.000000e+00
# 4.msaSize#6.density                     3.95900    0.0644***  1.050000e-10
# 4.msaSize#7.density                    14.08000     0.187***  1.290000e-07
# 5.msaSize#0.density                     1.00000          NaN           NaN
# 5.msaSize#1.density                     2.42600     0.0319**  1.810000e-03
# 5.msaSize#2.density                     2.99800    0.0481***  4.710000e-06
# 5.msaSize#3.density                     3.89900    0.0723***  0.000000e+00
# 5.msaSize#4.density                     4.45200    0.0858***  0.000000e+00
# 5.msaSize#5.density                     4.99400    0.0978***  0.000000e+00
# 5.msaSize#6.density                     6.49600     0.127***  0.000000e+00
# 5.msaSize#7.density                     9.96700     0.180***  0.000000e+00
# 1.msaRail                               1.05500     -0.00146  5.730000e-01
# 1.season                                0.85400   -0.0154***  0.000000e+00
# 2.season                                0.86700   -0.0136***  0.000000e+00
# 3.season                                1.05500    -0.000107  9.580000e-01
# 1.geographicCellDerived                 1.56000    0.0216***  8.540000e-04
# 2.geographicCellDerived                 1.05800      -0.0127  1.360000e-01
# 3.geographicCellDerived                 0.96900     -0.0192*  2.680000e-02
# 4.geographicCellDerived                 1.02400      -0.0131  8.590000e-02
# 5.geographicCellDerived                 0.75200   -0.0339***  2.700000e-05
# 6.geographicCellDerived                 1.37800      0.00862  2.750000e-01
# 7.geographicCellDerived                 1.16800     -0.00974  3.500000e-01
# 8.geographicCellDerived                 1.61800      0.00480  7.650000e-01
# 9.geographicCellDerived                 1.05900      -0.0127  1.360000e-01
# 10.geographicCellDerived                0.75000   -0.0345***  2.770000e-05
# 11.geographicCellDerived                1.54500     0.0196**  6.220000e-03
# 12.geographicCellDerived                0.95000     -0.0198*  1.720000e-02
# 13.geographicCellDerived                1.04800      -0.0146  1.070000e-01
# 14.geographicCellDerived                0.51700   -0.0489***  0.000000e+00
# 15.geographicCellDerived                1.31300      0.00595  4.150000e-01
# 16.geographicCellDerived                1.20900     -0.00766  4.730000e-01
# 17.geographicCellDerived                1.31600      0.00523  5.010000e-01
# 18.geographicCellDerived                0.92300    -0.0171**  6.610000e-03
# 19.geographicCellDerived                0.94400     -0.0167*  1.360000e-02
# Constant                                0.00559          NaN           NaN
# NaN                                         NaN          NaN           NaN
# Observations                                NaN      224,720           NaN
# Robust seeform in parentheses               NaN          NaN           NaN
# *** p<0.001, ** p<0.01, * p<0.05            NaN          NaN           NaN
#
#                                      ci_low   ci_high   coef.1  pval.2  \
# VARIABLES
# 2.hhSizeTopcode4                  -0.003660  0.018300      NaN     NaN
# 3.hhSizeTopcode4                  -0.043200 -0.019500      NaN     NaN
# 4.hhSizeTopcode4                  -0.061800 -0.037800      NaN     NaN
# 1.isWorker                         0.019500  0.025800      NaN     NaN
# 1.homeowner                       -0.023800 -0.016200      NaN     NaN
# 1.sex                              0.006500  0.010800      NaN     NaN
# 1.children0to12                   -0.005120  0.005140      NaN     NaN
# 1.children13to17                  -0.007090  0.004360      NaN     NaN
# 1.unrelated                        0.045000  0.068000      NaN     NaN
# 1.outOfTown                        0.053400  0.069700      NaN     NaN
# 1.dailySmartphoneUseHH             0.056700  0.064200      NaN     NaN
# 0.incomeCategory#c.vehPerHHMember -0.019400 -0.002840      NaN     NaN
# 1.incomeCategory#c.vehPerHHMember -0.019300 -0.004990      NaN     NaN
# 2.incomeCategory#c.vehPerHHMember -0.022100 -0.011400      NaN     NaN
# 3.incomeCategory#c.vehPerHHMember -0.016000 -0.002180      NaN     NaN
# 0.incomeCategory#c.pubTransCount   0.001470  0.002310      NaN     NaN
# 1.incomeCategory#c.pubTransCount   0.001740  0.002610      NaN     NaN
# 2.incomeCategory#c.pubTransCount   0.003020  0.003850      NaN     NaN
# 3.incomeCategory#c.pubTransCount   0.006030  0.007240      NaN     NaN
# 0.incomeCategory#c.walkCount       0.000069  0.000565      NaN     NaN
# 1.incomeCategory#c.walkCount       0.000332  0.000749      NaN     NaN
# 2.incomeCategory#c.walkCount       0.000546  0.000960      NaN     NaN
# 3.incomeCategory#c.walkCount       0.001390  0.002060      NaN     NaN
# 0.incomeCategory#c.bikeCount      -0.000154  0.001270      NaN     NaN
# 1.incomeCategory#c.bikeCount       0.001110  0.003230      NaN     NaN
# 2.incomeCategory#c.bikeCount       0.000782  0.003260      NaN     NaN
# 3.incomeCategory#c.bikeCount       0.003360  0.007000      NaN     NaN
# 0.incomeCategory#c.CNTTDTR         0.000073  0.002200      NaN     NaN
# 1.incomeCategory#c.CNTTDTR         0.000494  0.002280      NaN     NaN
# 2.incomeCategory#c.CNTTDTR         0.001660  0.003210      NaN     NaN
# 3.incomeCategory#c.CNTTDTR         0.003420  0.005440      NaN     NaN
# 1.hhSizeTopcode4#0.incomeCategory       NaN       NaN      NaN     NaN
# 1.hhSizeTopcode4#1.incomeCategory  0.014800  0.033300      NaN     NaN
# 1.hhSizeTopcode4#2.incomeCategory  0.063900  0.083000      NaN     NaN
# 1.hhSizeTopcode4#3.incomeCategory  0.142000  0.168000      NaN     NaN
# 2.hhSizeTopcode4#0.incomeCategory       NaN       NaN      NaN     NaN
# 2.hhSizeTopcode4#1.incomeCategory -0.007210  0.009060      NaN     NaN
# 2.hhSizeTopcode4#2.incomeCategory  0.024800  0.040100      NaN     NaN
# 2.hhSizeTopcode4#3.incomeCategory  0.098400  0.115000      NaN     NaN
# 3.hhSizeTopcode4#0.incomeCategory       NaN       NaN      NaN     NaN
# 3.hhSizeTopcode4#1.incomeCategory -0.009650  0.013600      NaN     NaN
# 3.hhSizeTopcode4#2.incomeCategory  0.006070  0.027800      NaN     NaN
# 3.hhSizeTopcode4#3.incomeCategory  0.079400  0.102000      NaN     NaN
# 4.hhSizeTopcode4#0.incomeCategory       NaN       NaN      NaN     NaN
# 4.hhSizeTopcode4#1.incomeCategory -0.014600  0.006440      NaN     NaN
# 4.hhSizeTopcode4#2.incomeCategory  0.001810  0.021100      NaN     NaN
# 4.hhSizeTopcode4#3.incomeCategory  0.070200  0.090900      NaN     NaN
# 1.race                            -0.031900  0.004060      NaN     NaN
# 2.race                            -0.021700 -0.011300      NaN     NaN
# 3.race                            -0.023100 -0.012700      NaN     NaN
# ...                                     ...       ...      ...     ...
# 3.msaSize#2.density                0.013800  0.036500      NaN     NaN
# 3.msaSize#3.density                0.019800  0.041000      NaN     NaN
# 3.msaSize#4.density                0.035800  0.057200      NaN     NaN
# 3.msaSize#5.density                0.035000  0.057200      NaN     NaN
# 3.msaSize#6.density                0.037300  0.076500      NaN     NaN
# 3.msaSize#7.density                0.027800  0.139000      NaN     NaN
# 4.msaSize#0.density                     NaN       NaN      NaN     NaN
# 4.msaSize#1.density               -0.006820  0.027200      NaN     NaN
# 4.msaSize#2.density                0.020900  0.060400      NaN     NaN
# 4.msaSize#3.density                0.025900  0.060700      NaN     NaN
# 4.msaSize#4.density                0.035100  0.067700      NaN     NaN
# 4.msaSize#5.density                0.052300  0.084100      NaN     NaN
# 4.msaSize#6.density                0.044900  0.083900      NaN     NaN
# 4.msaSize#7.density                0.118000  0.257000      NaN     NaN
# 5.msaSize#0.density                     NaN       NaN      NaN     NaN
# 5.msaSize#1.density                0.011900  0.052000      NaN     NaN
# 5.msaSize#2.density                0.027500  0.068700      NaN     NaN
# 5.msaSize#3.density                0.052900  0.091700      NaN     NaN
# 5.msaSize#4.density                0.067300  0.104000      NaN     NaN
# 5.msaSize#5.density                0.079700  0.116000      NaN     NaN
# 5.msaSize#6.density                0.107000  0.146000      NaN     NaN
# 5.msaSize#7.density                0.156000  0.204000      NaN     NaN
# 1.msaRail                         -0.006550  0.003630      NaN     NaN
# 1.season                          -0.019900 -0.010800      NaN     NaN
# 2.season                          -0.017400 -0.009760      NaN     NaN
# 3.season                          -0.004090  0.003880      NaN     NaN
# 1.geographicCellDerived            0.008890  0.034300      NaN     NaN
# 2.geographicCellDerived           -0.029300  0.003970      NaN     NaN
# 3.geographicCellDerived           -0.036200 -0.002210      NaN     NaN
# 4.geographicCellDerived           -0.028100  0.001860      NaN     NaN
# 5.geographicCellDerived           -0.049700 -0.018100      NaN     NaN
# 6.geographicCellDerived           -0.006860  0.024100      NaN     NaN
# 7.geographicCellDerived           -0.030200  0.010700      NaN     NaN
# 8.geographicCellDerived           -0.026700  0.036300      NaN     NaN
# 9.geographicCellDerived           -0.029300  0.004000      NaN     NaN
# 10.geographicCellDerived          -0.050600 -0.018400      NaN     NaN
# 11.geographicCellDerived           0.005550  0.033600      NaN     NaN
# 12.geographicCellDerived          -0.036200 -0.003510      NaN     NaN
# 13.geographicCellDerived          -0.032300  0.003140      NaN     NaN
# 14.geographicCellDerived          -0.061600 -0.036200      NaN     NaN
# 15.geographicCellDerived          -0.008340  0.020200      NaN     NaN
# 16.geographicCellDerived          -0.028600  0.013300      NaN     NaN
# 17.geographicCellDerived          -0.010000  0.020400      NaN     NaN
# 18.geographicCellDerived          -0.029400 -0.004760      NaN     NaN
# 19.geographicCellDerived          -0.030000 -0.003430      NaN     NaN
# Constant                                NaN       NaN      NaN     NaN
# NaN                                     NaN       NaN      NaN     NaN
# Observations                            NaN       NaN  221,128     NaN
# Robust seeform in parentheses           NaN       NaN      NaN     NaN
# *** p<0.001, ** p<0.01, * p<0.05        NaN       NaN      NaN     NaN
#
#                                    ci_low.1  ci_high.1
# VARIABLES
# 2.hhSizeTopcode4                        NaN        NaN
# 3.hhSizeTopcode4                        NaN        NaN
# 4.hhSizeTopcode4                        NaN        NaN
# 1.isWorker                              NaN        NaN
# 1.homeowner                             NaN        NaN
# 1.sex                                   NaN        NaN
# 1.children0to12                         NaN        NaN
# 1.children13to17                        NaN        NaN
# 1.unrelated                             NaN        NaN
# 1.outOfTown                             NaN        NaN
# 1.dailySmartphoneUseHH                  NaN        NaN
# 0.incomeCategory#c.vehPerHHMember       NaN        NaN
# 1.incomeCategory#c.vehPerHHMember       NaN        NaN
# 2.incomeCategory#c.vehPerHHMember       NaN        NaN
# 3.incomeCategory#c.vehPerHHMember       NaN        NaN
# 0.incomeCategory#c.pubTransCount        NaN        NaN
# 1.incomeCategory#c.pubTransCount        NaN        NaN
# 2.incomeCategory#c.pubTransCount        NaN        NaN
# 3.incomeCategory#c.pubTransCount        NaN        NaN
# 0.incomeCategory#c.walkCount            NaN        NaN
# 1.incomeCategory#c.walkCount            NaN        NaN
# 2.incomeCategory#c.walkCount            NaN        NaN
# 3.incomeCategory#c.walkCount            NaN        NaN
# 0.incomeCategory#c.bikeCount            NaN        NaN
# 1.incomeCategory#c.bikeCount            NaN        NaN
# 2.incomeCategory#c.bikeCount            NaN        NaN
# 3.incomeCategory#c.bikeCount            NaN        NaN
# 0.incomeCategory#c.CNTTDTR              NaN        NaN
# 1.incomeCategory#c.CNTTDTR              NaN        NaN
# 2.incomeCategory#c.CNTTDTR              NaN        NaN
# 3.incomeCategory#c.CNTTDTR              NaN        NaN
# 1.hhSizeTopcode4#0.incomeCategory       NaN        NaN
# 1.hhSizeTopcode4#1.incomeCategory       NaN        NaN
# 1.hhSizeTopcode4#2.incomeCategory       NaN        NaN
# 1.hhSizeTopcode4#3.incomeCategory       NaN        NaN
# 2.hhSizeTopcode4#0.incomeCategory       NaN        NaN
# 2.hhSizeTopcode4#1.incomeCategory       NaN        NaN
# 2.hhSizeTopcode4#2.incomeCategory       NaN        NaN
# 2.hhSizeTopcode4#3.incomeCategory       NaN        NaN
# 3.hhSizeTopcode4#0.incomeCategory       NaN        NaN
# 3.hhSizeTopcode4#1.incomeCategory       NaN        NaN
# 3.hhSizeTopcode4#2.incomeCategory       NaN        NaN
# 3.hhSizeTopcode4#3.incomeCategory       NaN        NaN
# 4.hhSizeTopcode4#0.incomeCategory       NaN        NaN
# 4.hhSizeTopcode4#1.incomeCategory       NaN        NaN
# 4.hhSizeTopcode4#2.incomeCategory       NaN        NaN
# 4.hhSizeTopcode4#3.incomeCategory       NaN        NaN
# 1.race                                  NaN        NaN
# 2.race                                  NaN        NaN
# 3.race                                  NaN        NaN
# ...                                     ...        ...
# 3.msaSize#2.density                     NaN        NaN
# 3.msaSize#3.density                     NaN        NaN
# 3.msaSize#4.density                     NaN        NaN
# 3.msaSize#5.density                     NaN        NaN
# 3.msaSize#6.density                     NaN        NaN
# 3.msaSize#7.density                     NaN        NaN
# 4.msaSize#0.density                     NaN        NaN
# 4.msaSize#1.density                     NaN        NaN
# 4.msaSize#2.density                     NaN        NaN
# 4.msaSize#3.density                     NaN        NaN
# 4.msaSize#4.density                     NaN        NaN
# 4.msaSize#5.density                     NaN        NaN
# 4.msaSize#6.density                     NaN        NaN
# 4.msaSize#7.density                     NaN        NaN
# 5.msaSize#0.density                     NaN        NaN
# 5.msaSize#1.density                     NaN        NaN
# 5.msaSize#2.density                     NaN        NaN
# 5.msaSize#3.density                     NaN        NaN
# 5.msaSize#4.density                     NaN        NaN
# 5.msaSize#5.density                     NaN        NaN
# 5.msaSize#6.density                     NaN        NaN
# 5.msaSize#7.density                     NaN        NaN
# 1.msaRail                               NaN        NaN
# 1.season                                NaN        NaN
# 2.season                                NaN        NaN
# 3.season                                NaN        NaN
# 1.geographicCellDerived                 NaN        NaN
# 2.geographicCellDerived                 NaN        NaN
# 3.geographicCellDerived                 NaN        NaN
# 4.geographicCellDerived                 NaN        NaN
# 5.geographicCellDerived                 NaN        NaN
# 6.geographicCellDerived                 NaN        NaN
# 7.geographicCellDerived                 NaN        NaN
# 8.geographicCellDerived                 NaN        NaN
# 9.geographicCellDerived                 NaN        NaN
# 10.geographicCellDerived                NaN        NaN
# 11.geographicCellDerived                NaN        NaN
# 12.geographicCellDerived                NaN        NaN
# 13.geographicCellDerived                NaN        NaN
# 14.geographicCellDerived                NaN        NaN
# 15.geographicCellDerived                NaN        NaN
# 16.geographicCellDerived                NaN        NaN
# 17.geographicCellDerived                NaN        NaN
# 18.geographicCellDerived                NaN        NaN
# 19.geographicCellDerived                NaN        NaN
# Constant                                NaN        NaN
# NaN                                     NaN        NaN
# Observations                            NaN        NaN
# Robust seeform in parentheses           NaN        NaN
# *** p<0.001, ** p<0.01, * p<0.05        NaN        NaN
#
# [142 rows x 13 columns]

# %%
main.insert(0, 'Variable', main.index)

# Marginal effects for MSA size are in a different column because they're estimated on a different sample
for i in range(1, 6):
    idx = main.index[main.Variable == f'{i}.msaSize'][0]
    main.loc[idx, 'coef'] = main.loc[idx, 'coef.1']
    main.loc[idx, 'pval.1'] = main.loc[idx, 'pval.2']
    main.loc[idx, 'ci_low'] = main.loc[idx, 'ci_low.1']
    main.loc[idx, 'ci_high'] = main.loc[idx, 'ci_high.1']

main = main.reset_index()
main['pos'] = main.index * 2
main = main.set_index('pos')

for firstVar, label in [
    ('2.hhSizeTopcode4', 'Household size'),
    ('0.incomeCategory#c.vehPerHHMember', 'Vehicles per household member'),
    ('0.incomeCategory#c.pubTransCount', 'Days used public transit in last 30 days'),
    ('0.incomeCategory#c.walkCount', 'Walk trips in last 7 days'),
    ('0.incomeCategory#c.bikeCount', 'Bike trips in last 7 days'),
    ('1.children0to12', 'Presence of children'),
    ('0.incomeCategory#c.CNTTDTR', 'Count of trips on travel day'),
    ('1.hhSizeTopcode4#1.incomeCategory', 'Income, household size 1'),
    ('2.hhSizeTopcode4#1.incomeCategory', 'Income, household size 2'),
    ('3.hhSizeTopcode4#1.incomeCategory', 'Income, household size 3'),
    ('4.hhSizeTopcode4#1.incomeCategory', 'Income, household size 4+'),
    ('0.msaSize#1.density', 'Home block group density, not in MSA'),
    ('1.msaSize#1.density', 'Home block group density, MSA with less than 250,000 people'),
    ('2.msaSize#1.density', 'Home block group density, MSA with 250,000 to 499,999 people'),
    ('3.msaSize#1.density', 'Home block group density, MSA with 500,000 to 999,999 people'),
    ('4.msaSize#1.density', 'Home block group density, MSA with 1,000,000 to 2,999,999 people'),
    ('5.msaSize#1.density', 'Home block group density, MSA with 3 million people or more'),
    ('1.race', 'Race'),
    ('1.agecat', 'Age'),
    ('1.msaSize', 'MSA size'),
]:
    if not np.any(main.Variable == firstVar):
        print(f'{firstVar} not found!')
    idx = main.index[main.Variable == firstVar][0]
    main.loc[idx - 1] =\
        pd.Series([r'\textbf{' + label + '}', '', '', '', '', '', '', '', ''
                  ], index=['Variable', 'coefEform', 'pval', 'ci_lowEform',
       'ci_highEform', 'coef', 'pval.1', 'ci_low', 'ci_high'])

# Variables that are not part of a group
loneVars = ['1.outOfTown', '1.isWorker', '1.unrelated', '1.isHispanic', '1.homeowner', '1.dailySmartphoneUseHH', '1.msaRail', '1.sex']
        
# Replace all vars with labels
main['Variable'] = main.Variable.replace({ k: (r'\ti ' + v) if k not in loneVars else v for k, v in {
'2.hhSizeTopcode4': 'Household size 2',
'3.hhSizeTopcode4': 'Household size 3',
'4.hhSizeTopcode4': 'Household size 4+',
'1.outOfTown': 'Out of town on travel day',
'0.incomeCategory#c.vehPerHHMember': r'\$24,999 or less',
'1.incomeCategory#c.vehPerHHMember': r'\$25,000-\$50,000',
'2.incomeCategory#c.vehPerHHMember': r'\$50,000-\$100,000',
'3.incomeCategory#c.vehPerHHMember': r'More than \$100,000',
'0.incomeCategory#c.pubTransCount': r'\$24,999 or less',
'1.incomeCategory#c.pubTransCount': r'\$25,000-\$50,000',
'2.incomeCategory#c.pubTransCount': r'\$50,000-\$100,000',
'3.incomeCategory#c.pubTransCount': r'More than \$100,000',
'0.incomeCategory#c.walkCount': r'\$24,999 or less',
'1.incomeCategory#c.walkCount': r'\$25,000-\$50,000',
'2.incomeCategory#c.walkCount': r'\$50,000-\$100,000',
'3.incomeCategory#c.walkCount': r'More than \$100,000',
'0.incomeCategory#c.bikeCount': r'\$24,999 or less',
'1.incomeCategory#c.bikeCount': r'\$25,000-\$50,000',
'2.incomeCategory#c.bikeCount': r'\$50,000-\$100,000',
'3.incomeCategory#c.bikeCount': r'More than \$100,000',
'0.incomeCategory#c.CNTTDTR': r'\$24,999 or less',
'1.incomeCategory#c.CNTTDTR': r'\$25,000-\$50,000',
'2.incomeCategory#c.CNTTDTR': r'\$50,000-\$100,000',
'3.incomeCategory#c.CNTTDTR': r'More than \$100,000',
'1.hhSizeTopcode4#1.incomeCategory': r'\$25,000-\$50,000',
'1.hhSizeTopcode4#2.incomeCategory': r'\$50,000-\$100,000',
'1.hhSizeTopcode4#3.incomeCategory': r'More than \$100,000',
'2.hhSizeTopcode4#1.incomeCategory': r'\$25,000-\$50,000',
'2.hhSizeTopcode4#2.incomeCategory': r'\$50,000-\$100,000',
'2.hhSizeTopcode4#3.incomeCategory': r'More than \$100,000',
'3.hhSizeTopcode4#1.incomeCategory': r'\$25,000-\$50,000',
'3.hhSizeTopcode4#2.incomeCategory': r'\$50,000-\$100,000',
'3.hhSizeTopcode4#3.incomeCategory': r'More than \$100,000',
'4.hhSizeTopcode4#1.incomeCategory': r'\$25,000-\$50,000',
'4.hhSizeTopcode4#2.incomeCategory': r'\$50,000-\$100,000',
'4.hhSizeTopcode4#3.incomeCategory': r'More than \$100,000',
'1.race': 'American Indian or Alaska Native',
'2.race': 'Asian',
'3.race': 'Black or African American',
'4.race': 'Multiple races',
'5.race': 'Native Hawaiian or other Pacific Islander',
'6.race': 'Other',
'1.agecat': '20-29',
'2.agecat': '30-39',
'3.agecat': '40-49',
'4.agecat': '50-59',
'5.agecat': '60-69',
'6.agecat': '70-79',
'7.agecat': '80+',
'1.msaSize': 'Less than 250,000\textsuperscript{\textdagger}',
'2.msaSize': '250,000-499,999\textsuperscript{\textdagger}',
'3.msaSize': '500,000-999,999\textsuperscript{\textdagger}',
'4.msaSize': '1,000,000-2,999,999\textsuperscript{\textdagger}',
'5.msaSize': 'More than 3,000,000\textsuperscript{\textdagger}',
'1.density': '100-499 persons/sq. mi.',
'2.density': '500-999 persons/sq. mi.',
'3.density': '1,000-1,999 persons/sq. mi.',
'4.density': '2,000-3,999 persons/sq. mi.',
'5.density': '4,000-9,999 persons/sq. mi.',
'6.density': '10,000-24,999 persons/sq. mi.',
'7.density': '25,000 persons/sq. mi. or more',
'1.isWorker': 'Worker',
'1.children0to12': 'Children 0-12',
'1.children13to17': 'Children 13-17',
'1.unrelated': 'No related adults in household',
'1.isHispanic': 'Hispanic',
'1.homeowner': 'Homeowner',
'1.msaRail': 'Heavy rail in MSA',
'0.msaSize#1.density': '100--499 persons/sq. mi.',
'0.msaSize#2.density': '500--999 persons/sq. mi.',
'0.msaSize#3.density': '1,000--1,999 persons/sq. mi.',
'0.msaSize#4.density': '2,000--3,999 persons/sq. mi.',
'0.msaSize#5.density': '4,000--9,999 persons/sq. mi.',
'0.msaSize#6.density': '10,000--24,999 persons/sq. mi.',
'0.msaSize#7.density': '> 25,000 persons/sq. mi.',
'1.msaSize#1.density': '100--499 persons/sq. mi.',
'1.msaSize#2.density': '500--999 persons/sq. mi.',
'1.msaSize#3.density': '1,000--1,999 persons/sq. mi.',
'1.msaSize#4.density': '2,000--3,999 persons/sq. mi.',
'1.msaSize#5.density': '4,000--9,999 persons/sq. mi.',
'1.msaSize#6.density': '10,000--24,999 persons/sq. mi.',
'1.msaSize#7.density': '> 25,000 persons/sq. mi.',
'2.msaSize#1.density': '100--499 persons/sq. mi.',
'2.msaSize#2.density': '500--999 persons/sq. mi.',
'2.msaSize#3.density': '1,000--1,999 persons/sq. mi.',
'2.msaSize#4.density': '2,000--3,999 persons/sq. mi.',
'2.msaSize#5.density': '4,000--9,999 persons/sq. mi.',
'2.msaSize#6.density': '10,000--24,999 persons/sq. mi.',
'2.msaSize#7.density': '> 25,000 persons/sq. mi.',
'3.msaSize#1.density': '100--499 persons/sq. mi.',
'3.msaSize#2.density': '500--999 persons/sq. mi.',
'3.msaSize#3.density': '1,000--1,999 persons/sq. mi.',
'3.msaSize#4.density': '2,000--3,999 persons/sq. mi.',
'3.msaSize#5.density': '4,000--9,999 persons/sq. mi.',
'3.msaSize#6.density': '10,000--24,999 persons/sq. mi.',
'3.msaSize#7.density': '> 25,000 persons/sq. mi.',
'4.msaSize#1.density': '100--499 persons/sq. mi.',
'4.msaSize#2.density': '500--999 persons/sq. mi.',
'4.msaSize#3.density': '1,000--1,999 persons/sq. mi.',
'4.msaSize#4.density': '2,000--3,999 persons/sq. mi.',
'4.msaSize#5.density': '4,000--9,999 persons/sq. mi.',
'4.msaSize#6.density': '10,000--24,999 persons/sq. mi.',
'4.msaSize#7.density': '> 25,000 persons/sq. mi.',
'5.msaSize#1.density': '100--499 persons/sq. mi.',
'5.msaSize#2.density': '500--999 persons/sq. mi.',
'5.msaSize#3.density': '1,000--1,999 persons/sq. mi.',
'5.msaSize#4.density': '2,000--3,999 persons/sq. mi.',
'5.msaSize#5.density': '4,000--9,999 persons/sq. mi.',
'5.msaSize#6.density': '10,000--24,999 persons/sq. mi.',
'5.msaSize#7.density': '> 25,000 persons/sq. mi.',
'1.dailySmartphoneUseHH': 'Daily smartphone use by a household member',
'1.sex': 'Male'
}.items()})

main = main.sort_index()

# %%
with pd.option_context("max_colwidth", 1000, 'display.float_format', lambda x: '%.3f' % x):
    main[[c for c in main.columns if c not in ['LABELS', 'VARIABLES', 'coef.1', 'pval.2', 'ci_low.1', 'ci_high.1']]]\
        [~pd.isnull(main.pval)]\
        .rename(columns={
            'ci_lowEform': 'ci_lowE',
            'ci_highEform': 'ci_highE',
            'coef': 'Marg. Eff.',
            'coefEform': 'Odds Rat.'
        })\
        .round(3)\
        .fillna('-')\
        .to_latex('../stata/result_table.tex', index=False, escape=False, longtable=True)

# %%
with pd.option_context('display.max_rows', 500):
    display(main)
# Out:
#                               VARIABLES  \
# pos
# -1                                  NaN
#  0                     2.hhSizeTopcode4
#  2                     3.hhSizeTopcode4
#  4                     4.hhSizeTopcode4
#  6                           1.isWorker
#  8                          1.homeowner
#  10                               1.sex
#  11                                 NaN
#  12                     1.children0to12
#  14                    1.children13to17
#  16                         1.unrelated
#  18                         1.outOfTown
#  20              1.dailySmartphoneUseHH
#  21                                 NaN
#  22   0.incomeCategory#c.vehPerHHMember
#  24   1.incomeCategory#c.vehPerHHMember
#  26   2.incomeCategory#c.vehPerHHMember
#  28   3.incomeCategory#c.vehPerHHMember
#  29                                 NaN
#  30    0.incomeCategory#c.pubTransCount
#  32    1.incomeCategory#c.pubTransCount
#  34    2.incomeCategory#c.pubTransCount
#  36    3.incomeCategory#c.pubTransCount
#  37                                 NaN
#  38        0.incomeCategory#c.walkCount
#  40        1.incomeCategory#c.walkCount
#  42        2.incomeCategory#c.walkCount
#  44        3.incomeCategory#c.walkCount
#  45                                 NaN
#  46        0.incomeCategory#c.bikeCount
#  48        1.incomeCategory#c.bikeCount
#  50        2.incomeCategory#c.bikeCount
#  52        3.incomeCategory#c.bikeCount
#  53                                 NaN
#  54          0.incomeCategory#c.CNTTDTR
#  56          1.incomeCategory#c.CNTTDTR
#  58          2.incomeCategory#c.CNTTDTR
#  60          3.incomeCategory#c.CNTTDTR
#  62   1.hhSizeTopcode4#0.incomeCategory
#  63                                 NaN
#  64   1.hhSizeTopcode4#1.incomeCategory
#  66   1.hhSizeTopcode4#2.incomeCategory
#  68   1.hhSizeTopcode4#3.incomeCategory
#  70   2.hhSizeTopcode4#0.incomeCategory
#  71                                 NaN
#  72   2.hhSizeTopcode4#1.incomeCategory
#  74   2.hhSizeTopcode4#2.incomeCategory
#  76   2.hhSizeTopcode4#3.incomeCategory
#  78   3.hhSizeTopcode4#0.incomeCategory
#  79                                 NaN
#  80   3.hhSizeTopcode4#1.incomeCategory
#  82   3.hhSizeTopcode4#2.incomeCategory
#  84   3.hhSizeTopcode4#3.incomeCategory
#  86   4.hhSizeTopcode4#0.incomeCategory
#  87                                 NaN
#  88   4.hhSizeTopcode4#1.incomeCategory
#  90   4.hhSizeTopcode4#2.incomeCategory
#  92   4.hhSizeTopcode4#3.incomeCategory
#  93                                 NaN
#  94                              1.race
#  96                              2.race
#  98                              3.race
#  100                             4.race
#  102                             5.race
#  104                             6.race
#  106                       1.isHispanic
#  107                                NaN
#  108                           1.agecat
#  110                           2.agecat
#  112                           3.agecat
#  114                           4.agecat
#  116                           5.agecat
#  118                           6.agecat
#  120                           7.agecat
#  121                                NaN
#  122                          1.msaSize
#  124                          2.msaSize
#  126                          3.msaSize
#  128                          4.msaSize
#  130                          5.msaSize
#  132                0.msaSize#0.density
#  133                                NaN
#  134                0.msaSize#1.density
#  136                0.msaSize#2.density
#  138                0.msaSize#3.density
#  140                0.msaSize#4.density
#  142                0.msaSize#5.density
#  144                0.msaSize#6.density
#  146                0.msaSize#7.density
#  148                1.msaSize#0.density
#  149                                NaN
#  150                1.msaSize#1.density
#  152                1.msaSize#2.density
#  154                1.msaSize#3.density
#  156                1.msaSize#4.density
#  158                1.msaSize#5.density
#  160                1.msaSize#6.density
#  162                1.msaSize#7.density
#  164                2.msaSize#0.density
#  165                                NaN
#  166                2.msaSize#1.density
#  168                2.msaSize#2.density
#  170                2.msaSize#3.density
#  172                2.msaSize#4.density
#  174                2.msaSize#5.density
#  176                2.msaSize#6.density
#  178                2.msaSize#7.density
#  180                3.msaSize#0.density
#  181                                NaN
#  182                3.msaSize#1.density
#  184                3.msaSize#2.density
#  186                3.msaSize#3.density
#  188                3.msaSize#4.density
#  190                3.msaSize#5.density
#  192                3.msaSize#6.density
#  194                3.msaSize#7.density
#  196                4.msaSize#0.density
#  197                                NaN
#  198                4.msaSize#1.density
#  200                4.msaSize#2.density
#  202                4.msaSize#3.density
#  204                4.msaSize#4.density
#  206                4.msaSize#5.density
#  208                4.msaSize#6.density
#  210                4.msaSize#7.density
#  212                5.msaSize#0.density
#  213                                NaN
#  214                5.msaSize#1.density
#  216                5.msaSize#2.density
#  218                5.msaSize#3.density
#  220                5.msaSize#4.density
#  222                5.msaSize#5.density
#  224                5.msaSize#6.density
#  226                5.msaSize#7.density
#  228                          1.msaRail
#  230                           1.season
#  232                           2.season
#  234                           3.season
#  236            1.geographicCellDerived
#  238            2.geographicCellDerived
#  240            3.geographicCellDerived
#  242            4.geographicCellDerived
#  244            5.geographicCellDerived
#  246            6.geographicCellDerived
#  248            7.geographicCellDerived
#  250            8.geographicCellDerived
#  252            9.geographicCellDerived
#  254           10.geographicCellDerived
#  256           11.geographicCellDerived
#  258           12.geographicCellDerived
#  260           13.geographicCellDerived
#  262           14.geographicCellDerived
#  264           15.geographicCellDerived
#  266           16.geographicCellDerived
#  268           17.geographicCellDerived
#  270           18.geographicCellDerived
#  272           19.geographicCellDerived
#  274                           Constant
#  276                                NaN
#  278                       Observations
#  280      Robust seeform in parentheses
#  282   *** p<0.001, ** p<0.01, * p<0.05
#
#                                                Variable  \
# pos
# -1                              \textbf{Household size}
#  0                                 \ti Household size 2
#  2                                 \ti Household size 3
#  4                                \ti Household size 4+
#  6                                               Worker
#  8                                            Homeowner
#  10                                                Male
#  11                       \textbf{Presence of children}
#  12                                   \ti Children 0-12
#  14                                  \ti Children 13-17
#  16                      No related adults in household
#  18                           Out of town on travel day
#  20          Daily smartphone use by a household member
#  21              \textbf{Vehicles per household member}
#  22                                \ti \$24,999 or less
#  24                               \ti \$25,000-\$50,000
#  26                              \ti \$50,000-\$100,000
#  28                             \ti More than \$100,000
#  29   \textbf{Days used public transit in last 30 days}
#  30                                \ti \$24,999 or less
#  32                               \ti \$25,000-\$50,000
#  34                              \ti \$50,000-\$100,000
#  36                             \ti More than \$100,000
#  37                  \textbf{Walk trips in last 7 days}
#  38                                \ti \$24,999 or less
#  40                               \ti \$25,000-\$50,000
#  42                              \ti \$50,000-\$100,000
#  44                             \ti More than \$100,000
#  45                  \textbf{Bike trips in last 7 days}
#  46                                \ti \$24,999 or less
#  48                               \ti \$25,000-\$50,000
#  50                              \ti \$50,000-\$100,000
#  52                             \ti More than \$100,000
#  53               \textbf{Count of trips on travel day}
#  54                                \ti \$24,999 or less
#  56                               \ti \$25,000-\$50,000
#  58                              \ti \$50,000-\$100,000
#  60                             \ti More than \$100,000
#  62                   1.hhSizeTopcode4#0.incomeCategory
#  63                   \textbf{Income, household size 1}
#  64                               \ti \$25,000-\$50,000
#  66                              \ti \$50,000-\$100,000
#  68                             \ti More than \$100,000
#  70                   2.hhSizeTopcode4#0.incomeCategory
#  71                   \textbf{Income, household size 2}
#  72                               \ti \$25,000-\$50,000
#  74                              \ti \$50,000-\$100,000
#  76                             \ti More than \$100,000
#  78                   3.hhSizeTopcode4#0.incomeCategory
#  79                   \textbf{Income, household size 3}
#  80                               \ti \$25,000-\$50,000
#  82                              \ti \$50,000-\$100,000
#  84                             \ti More than \$100,000
#  86                   4.hhSizeTopcode4#0.incomeCategory
#  87                  \textbf{Income, household size 4+}
#  88                               \ti \$25,000-\$50,000
#  90                              \ti \$50,000-\$100,000
#  92                             \ti More than \$100,000
#  93                                       \textbf{Race}
#  94                \ti American Indian or Alaska Native
#  96                                           \ti Asian
#  98                       \ti Black or African American
#  100                                 \ti Multiple races
#  102      \ti Native Hawaiian or other Pacific Islander
#  104                                          \ti Other
#  106                                           Hispanic
#  107                                       \textbf{Age}
#  108                                          \ti 20-29
#  110                                          \ti 30-39
#  112                                          \ti 40-49
#  114                                          \ti 50-59
#  116                                          \ti 60-69
#  118                                          \ti 70-79
#  120                                            \ti 80+
#  121                                  \textbf{MSA size}
#  122  \ti Less than 250,000\textsuperscript{\textdag...
#  124   \ti 250,000-499,999\textsuperscript{\textdagger}
#  126   \ti 500,000-999,999\textsuperscript{\textdagger}
#  128  \ti 1,000,000-2,999,999\textsuperscript{\textd...
#  130  \ti More than 3,000,000\textsuperscript{\textd...
#  132                                0.msaSize#0.density
#  133      \textbf{Home block group density, not in MSA}
#  134                       \ti 100--499 persons/sq. mi.
#  136                       \ti 500--999 persons/sq. mi.
#  138                   \ti 1,000--1,999 persons/sq. mi.
#  140                   \ti 2,000--3,999 persons/sq. mi.
#  142                   \ti 4,000--9,999 persons/sq. mi.
#  144                 \ti 10,000--24,999 persons/sq. mi.
#  146                       \ti > 25,000 persons/sq. mi.
#  148                                1.msaSize#0.density
#  149  \textbf{Home block group density, MSA with les...
#  150                       \ti 100--499 persons/sq. mi.
#  152                       \ti 500--999 persons/sq. mi.
#  154                   \ti 1,000--1,999 persons/sq. mi.
#  156                   \ti 2,000--3,999 persons/sq. mi.
#  158                   \ti 4,000--9,999 persons/sq. mi.
#  160                 \ti 10,000--24,999 persons/sq. mi.
#  162                       \ti > 25,000 persons/sq. mi.
#  164                                2.msaSize#0.density
#  165  \textbf{Home block group density, MSA with 250...
#  166                       \ti 100--499 persons/sq. mi.
#  168                       \ti 500--999 persons/sq. mi.
#  170                   \ti 1,000--1,999 persons/sq. mi.
#  172                   \ti 2,000--3,999 persons/sq. mi.
#  174                   \ti 4,000--9,999 persons/sq. mi.
#  176                 \ti 10,000--24,999 persons/sq. mi.
#  178                       \ti > 25,000 persons/sq. mi.
#  180                                3.msaSize#0.density
#  181  \textbf{Home block group density, MSA with 500...
#  182                       \ti 100--499 persons/sq. mi.
#  184                       \ti 500--999 persons/sq. mi.
#  186                   \ti 1,000--1,999 persons/sq. mi.
#  188                   \ti 2,000--3,999 persons/sq. mi.
#  190                   \ti 4,000--9,999 persons/sq. mi.
#  192                 \ti 10,000--24,999 persons/sq. mi.
#  194                       \ti > 25,000 persons/sq. mi.
#  196                                4.msaSize#0.density
#  197  \textbf{Home block group density, MSA with 1,0...
#  198                       \ti 100--499 persons/sq. mi.
#  200                       \ti 500--999 persons/sq. mi.
#  202                   \ti 1,000--1,999 persons/sq. mi.
#  204                   \ti 2,000--3,999 persons/sq. mi.
#  206                   \ti 4,000--9,999 persons/sq. mi.
#  208                 \ti 10,000--24,999 persons/sq. mi.
#  210                       \ti > 25,000 persons/sq. mi.
#  212                                5.msaSize#0.density
#  213  \textbf{Home block group density, MSA with 3 m...
#  214                       \ti 100--499 persons/sq. mi.
#  216                       \ti 500--999 persons/sq. mi.
#  218                   \ti 1,000--1,999 persons/sq. mi.
#  220                   \ti 2,000--3,999 persons/sq. mi.
#  222                   \ti 4,000--9,999 persons/sq. mi.
#  224                 \ti 10,000--24,999 persons/sq. mi.
#  226                       \ti > 25,000 persons/sq. mi.
#  228                                  Heavy rail in MSA
#  230                                           1.season
#  232                                           2.season
#  234                                           3.season
#  236                            1.geographicCellDerived
#  238                            2.geographicCellDerived
#  240                            3.geographicCellDerived
#  242                            4.geographicCellDerived
#  244                            5.geographicCellDerived
#  246                            6.geographicCellDerived
#  248                            7.geographicCellDerived
#  250                            8.geographicCellDerived
#  252                            9.geographicCellDerived
#  254                           10.geographicCellDerived
#  256                           11.geographicCellDerived
#  258                           12.geographicCellDerived
#  260                           13.geographicCellDerived
#  262                           14.geographicCellDerived
#  264                           15.geographicCellDerived
#  266                           16.geographicCellDerived
#  268                           17.geographicCellDerived
#  270                           18.geographicCellDerived
#  272                           19.geographicCellDerived
#  274                                           Constant
#  276                                                NaN
#  278                                       Observations
#  280                      Robust seeform in parentheses
#  282                   *** p<0.001, ** p<0.01, * p<0.05
#
#                                                  LABELS   coefEform      pval  \
# pos
# -1                                                  NaN
#  0                                   hhSizeTopcode4 = 2    1.380***  0.000659
#  2                                   hhSizeTopcode4 = 3       0.913     0.492
#  4                                   hhSizeTopcode4 = 4     0.687**   0.00767
#  6                                         isWorker = 1    1.412***         0
#  8                                        homeowner = 1    0.752***         0
#  10                                       sex = 1, Male    1.135***         0
#  11                                                 NaN
#  12                                   children0to12 = 1       1.000     0.998
#  14                                  children13to17 = 1       0.980     0.642
#  16                                       unrelated = 1    2.045***         0
#  18                                       outOfTown = 1    2.110***         0
#  20                            dailySmartphoneUseHH = 1    3.141***         0
#  21                                                 NaN
#  22                                                 NaN     0.794**   0.00781
#  24                                                 NaN    0.770***  0.000793
#  26                                                 NaN    0.753***  5.59e-10
#  28                                                 NaN     0.918**   0.00996
#  29                                                 NaN
#  30                                                 NaN    1.040***         0
#  32                                                 NaN    1.048***         0
#  34                                                 NaN    1.060***         0
#  36                                                 NaN    1.065***         0
#  37                                                 NaN
#  38                                                 NaN      1.007*    0.0121
#  40                                                 NaN    1.012***  3.45e-07
#  42                                                 NaN    1.013***         0
#  44                                                 NaN    1.016***         0
#  45                                                 NaN
#  46                                                 NaN       1.012     0.125
#  48                                                 NaN    1.048***   5.7e-05
#  50                                                 NaN     1.035**   0.00137
#  52                                                 NaN    1.050***  2.46e-08
#  53                                                 NaN
#  54                                                 NaN      1.024*    0.0367
#  56                                                 NaN     1.030**   0.00224
#  58                                                 NaN    1.042***   7.5e-10
#  60                                                 NaN    1.043***         0
#  62                                                 NaN           1       NaN
#  63                                                 NaN
#  64                                                 NaN       1.270      0.11
#  66                                                 NaN    2.083***  4.54e-09
#  68                                                 NaN    3.500***         0
#  70                                                 NaN           1       NaN
#  71                                                 NaN
#  72                                                 NaN       0.920      0.55
#  74                                                 NaN     1.456**   0.00142
#  76                                                 NaN    2.867***         0
#  78                                                 NaN           1       NaN
#  79                                                 NaN
#  80                                                 NaN       0.956     0.778
#  82                                                 NaN       1.190     0.204
#  84                                                 NaN    2.602***         0
#  86                                                 NaN           1       NaN
#  87                                                 NaN
#  88                                                 NaN       0.832     0.255
#  90                                                 NaN       1.135      0.35
#  92                                                 NaN    2.647***         0
#  93                                                 NaN
#  94          race = 1, American Indian or Alaska Native       0.812     0.152
#  96                                     race = 2, Asian    0.779***  4.13e-09
#  98                 race = 3, Black or African American    0.762***  2.05e-10
#  100                           race = 4, Multiple races      0.897*    0.0456
#  102  race = 5, Native Hawaiian or other Pacific Isl...       0.955     0.787
#  104                                    race = 6, Other      0.846*    0.0136
#  106                                     isHispanic = 1     0.899**   0.00559
#  107                                                NaN
#  108                               agecat = 1, [20, 30)    2.663***         0
#  110                               agecat = 2, [30, 40)    1.949***         0
#  112                               agecat = 3, [40, 50)      1.131*    0.0446
#  114                               agecat = 4, [50, 60)    0.647***         0
#  116                               agecat = 5, [60, 70)    0.446***         0
#  118                               agecat = 6, [70, 80)    0.312***         0
#  120                               agecat = 7, [80, 90)    0.289***         0
#  121                                                NaN
#  122                     msaSize = 1, Less than 250,000      1.453*    0.0108
#  124                    msaSize = 2, 250,000 to 499,999       1.197     0.357
#  126                    msaSize = 3, 500,000 to 999,999       1.193     0.345
#  128                msaSize = 4, 1,000,000 to 2,999,999    1.945***  0.000507
#  130                   msaSize = 5, More than 3 million     1.855**   0.00159
#  132                                                NaN           1       NaN
#  133                                                NaN
#  134                                                NaN       1.077     0.604
#  136                                                NaN       1.314     0.108
#  138                                                NaN       1.290     0.139
#  140                                                NaN       1.082     0.688
#  142                                                NaN       1.103     0.688
#  144                                                NaN       0.832     0.793
#  146                                                NaN           1       NaN
#  148                                                NaN           1       NaN
#  149                                                NaN
#  150                                                NaN       0.940     0.666
#  152                                                NaN       1.084     0.601
#  154                                                NaN     1.451**   0.00823
#  156                                                NaN       1.273    0.0845
#  158                                                NaN     1.569**   0.00173
#  160                                                NaN       1.381      0.28
#  162                                                NaN      4.676*    0.0234
#  164                                                NaN           1       NaN
#  165                                                NaN
#  166                                                NaN      1.562*    0.0271
#  168                                                NaN    2.053***    0.0004
#  170                                                NaN    2.500***  1.98e-06
#  172                                                NaN    2.572***  5.54e-07
#  174                                                NaN    2.777***  5.01e-08
#  176                                                NaN    3.735***   1.7e-09
#  178                                                NaN      3.170*     0.044
#  180                                                NaN           1       NaN
#  181                                                NaN
#  182                                                NaN      1.462*    0.0404
#  184                                                NaN    2.077***  7.58e-05
#  186                                                NaN    2.317***  2.01e-06
#  188                                                NaN    3.097***  5.07e-11
#  190                                                NaN    3.076***  1.51e-10
#  192                                                NaN    3.632***  8.87e-10
#  194                                                NaN    5.110***  7.64e-06
#  196                                                NaN           1       NaN
#  197                                                NaN
#  198                                                NaN       1.242     0.259
#  200                                                NaN    2.044***  0.000223
#  202                                                NaN    2.118***  3.45e-05
#  204                                                NaN    2.356***  1.01e-06
#  206                                                NaN    2.876***  8.59e-10
#  208                                                NaN    2.755***  4.34e-08
#  210                                                NaN    7.944***         0
#  212                                                NaN           1       NaN
#  213                                                NaN
#  214                                                NaN     1.686**   0.00487
#  216                                                NaN    2.087***  6.87e-05
#  218                                                NaN    2.756***  1.04e-08
#  220                                                NaN    3.168***         0
#  222                                                NaN    3.561***         0
#  224                                                NaN    4.605***         0
#  226                                                NaN    6.967***         0
#  228                                        msaRail = 1       0.979     0.574
#  230                                 season = 1, Spring    0.798***  8.98e-11
#  232                                 season = 2, Summer    0.820***         0
#  234                                 season = 3, Winter       0.999     0.958
#  236              geographicCellDerived = 1, California     1.315**   0.00175
#  238  geographicCellDerived = 2, Census division 1 (...       0.834     0.135
#  240  geographicCellDerived = 3, Census division 2 (...      0.753*    0.0276
#  242  geographicCellDerived = 4, Census division 3 (...       0.828    0.0817
#  244  geographicCellDerived = 5, Census division 4 (...    0.585***  3.09e-05
#  246  geographicCellDerived = 6, Census division 5 (...       1.121     0.279
#  248  geographicCellDerived = 7, Census division 6 (...       0.871     0.356
#  250  geographicCellDerived = 8, Census division 7 (...       1.066     0.762
#  252  geographicCellDerived = 9, Census division 8 (...       0.834     0.137
#  254  geographicCellDerived = 10, Census division 9 ...    0.578***  3.55e-05
#  256                geographicCellDerived = 11, Georgia     1.283**   0.00842
#  258                   geographicCellDerived = 12, Iowa      0.746*    0.0175
#  260               geographicCellDerived = 13, Maryland       0.810     0.109
#  262         geographicCellDerived = 14, New York State    0.430***         0
#  264         geographicCellDerived = 15, North Carolina       1.083     0.419
#  266               geographicCellDerived = 16, Oklahoma       0.898     0.478
#  268         geographicCellDerived = 17, South Carolina       1.072     0.503
#  270                  geographicCellDerived = 18, Texas     0.779**   0.00397
#  272              geographicCellDerived = 19, Wisconsin      0.784*    0.0101
#  274                                           Constant  0.00387***         0
#  276                                                NaN         NaN       NaN
#  278                                                NaN     224,720       NaN
#  280                                                NaN         NaN       NaN
#  282                                                NaN         NaN       NaN
#
#      ci_lowEform ci_highEform         coef    pval.1    ci_low   ci_high  \
# pos
# -1
#  0         1.146        1.661      0.00732     0.191  -0.00366    0.0183
#  2         0.704        1.184   -0.0314***  2.14e-07   -0.0432   -0.0195
#  4         0.521        0.905   -0.0498***         0   -0.0618   -0.0378
#  6         1.344        1.483    0.0226***         0    0.0195    0.0258
#  8         0.713        0.793   -0.0200***         0   -0.0238   -0.0162
#  10          1.1        1.171   0.00864***         0    0.0065    0.0108
#  11
#  12        0.928        1.078     6.59e-06     0.998  -0.00512   0.00514
